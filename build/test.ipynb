# %%
import mstmap

mst = mstmap.MSTmap()

# %%
mst.set_default_args()
mst.set_input_file("../example_noargs.txt")
mst.run(quiet=False)
# Out:
# Population type: DH
# Population name: LG
# Distance function: kosambi
# Cutoff p-value: 2
# No. mapping distance threshold (cM): 15
# No. mapping size threshold: 0
# Missing threshold: 1
# Estimation before clustering: no
# Detect bad data: yes
# Objective function: COUNT
# Number of loci: 100
# Number of individual: 100
# Input file: ../example_noargs.txt
# Output file: output.txt
# calculating the pair-wise hamming distance
# start calculating pair-wise distance1722019756
# finished calculating pair-wise distance:1722019756
# finished calculating the pair-wise hamming distance
# number_of_recombinations_cut_off: 1.79769e+308
# found 1 connected components
# order markers version 2
# initial number of cross-overs:288.917
# mask threshold in this iteration: 0.75
# identified 109 data points in this iteration
# current number of errors plus cross-overs:217.901
# mask threshold in this iteration: 0.75
# identified 17 data points in this iteration
# ...

# %%
mst.run_from_file("../example.txt", quiet=True)

# %%
mst.get_lg_cost_by_index(1)
# Out:
# ---------------------------------------------------------------------------
# MSTmapRuntimeError                        Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mst.get_lg_cost_by_index(1)
#
# MSTmapRuntimeError: Index out of range.
